# %% [markdown]
# # Template Casus 2 — Data preparatie, modelleren en evalueren

# %% [markdown]
# Je kunt dit template gebruijken bij het maken van casus 2. Je mag hiervan afwijken, als je denkt dat je werk daar beter van wordt.
#
# Bekijk ook nog even de tips uit het template van casus 1. Die zijn ook hier van toepassing.

# %% [markdown]
# ## Introductie
#
# Het algemene doel van de casus is reeds beschreven in het vorige notebook. Beschrijf hier het doel van dit notebook en welke stappen je uit gaat voeren. Een interactieve inhoudsopgave is handig. Beschrijf ook kort wat je verwacht te vinden.

# %% [markdown]
# ## 1. Data inlezen en splitten
#
# Lees de (opgeschoonde) data in en maak een train/val/test split.

# %% [markdown]
# ## 2. Modelkeuze
#
# Beschrijf hier welk(e) model(len) je wilt gaan trainen en waarom dat een geschikt model zou kunnen zijn.

# %% [markdown]
# ## 3. Data preparatie
#
# ### 3.a. Plan voor datapreparatie
#
# Hier beschrijf je wat voor datapreparatiestappen je gaat doen. Dit hangt samen met de keuzes voor je model. Als je meerdere dingen uit wilt proberen (bijvoorbeeld een model trainen met en zonder standaardisatie), benoem dan beide opties en licht toe welke je als eerst gaat doen.

# %% [markdown]
# ### 3.b. Bewerkingen op de trainset
#
# Voer je bewerkingen uit op de trainset. Gebruik het stappenplan per bewerking.

# %% [markdown]
# ### 3.c. Bewerkingen op de validatieset
#
# Herhaal dezelfde bewerkingen op de validatieset.

# %% [markdown]
# ## 4. Modelleren
#
# ### 4.a. Baseline model
#
# Maak een simpel baseline model en bepaal de bijbehorende metrics.

# %% [markdown]
# ### 4.b. Model *x*
#
# #### Trainen
#
# Train je eerste model als startpunt op de trainset. Je hoeft dit nog niet te optimaliseren door instellingen aan te passen (train het model dus met de standaardinstellingen), je wilt eerst een eerlijk vertrekpunt om vanaf te verbeteren.
#
# Voor elk model kun je deze cel kopiëren en daaronder de code runnen om het model te trainen.

# %% [markdown]
# #### Evalueren
#
# Evalueer je model op de validatieset, gebruik passende metrics. Vergelijk deze met de resultaten op de trainset om overfitting uit te sluiten.
#
# Voor elk model kun je deze cel kopiëren en daaronder de code runnen om het model te trainen.

# %% [markdown]
# ### 4.x. Conclusie
#
# Analyseer welk model de beste resultaten heeft en in de volgende stap verbeterd gaat worden.

# %% [markdown]
# ## 5. Model verbeteren
#
# Kies het beste of de *x* beste modellen en probeer deze te verbeteren. Dat kan door hyperparameters te tunen, de feature set aan te passen of een andere datapreparatie uit te voeren. Licht telkens duidelijk toe wat je gaat veranderen en waarom. Gebruik de validatieset om te bepalen wat het beste model is. Maak hiervoor een duidelijk overzicht (bijvoorbeeld een tabel) van al je gevonden waarden.
#
# Probeer minstens 3 verbeteringen. Maak logische kopjes in markdown met duidelijke titels en nummering.

# %% [markdown]
# ## 6. Eindevaluatie op de testset
#
# Je hebt je model gekozen op basis van de validatieset. Voer nu de bijbehorende datapreparatiestappen uit, train het model op de *beste* manier en evalueer je gekozen model op de testset.

# %% [markdown]
# ## 7. Resultaten, conclusie & vervolg
#
# Breng je bevindingen samen. Geef antwoord op je onderzoeksvraag, beschrijf hoe goed je model presteert en waar de belangrijkste beperkingen zitten. Verwijs daarbij naar je resultaten uit de vorige stappen. Heb je nog aanbevelingen over hoe het model nog beter kan?

# %% [markdown]
# ## 8. Reflectie
#
# Reflecteer kort op wat je hebt gedaan. Wat verraste je? Wat vond je lastig? Wat zou je met meer tijd nog gedaan willen hebben?
